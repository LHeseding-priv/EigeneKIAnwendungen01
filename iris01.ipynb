# %% [markdown]
# Benötigte Module importieren und Datei laden. Die ersten Zellen werden ausgegeben.

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split

path = "./docs/Daten/iris.csv"
data = pd.read_csv(path, delimiter=',')
print(data.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# Daten vorbereiten

# %%
# Was soll vorhergesagt werden? Spaltenname in Variable speichern.
col_name = "species"

# Zeichenketten in Zahlen umwandeln
data[col_name] = data[col_name].astype('category')
data[col_name] = data[col_name].cat.codes

# Hier findet die Aufteilung in zwei Tabellen statt (Input=data und Output=col).
col = data[col_name]
data = data.drop([col_name], axis=1)

# %% [markdown]
# KNN aufbauen

# %%
# Aus den zwei tabellen vier Tabellen erstellen: Trainingsdaten, Testdaten, Trainingslabels, Testlabels
train_data, test_data, train_col, test_col = train_test_split(data, col, test_size=0.2)

# Aufbau KNN
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation=tf.nn.sigmoid, input_dim=4),
    tf.keras.layers.Dense(64, activation=tf.nn.sigmoid),
    tf.keras.layers.Dense(3, activation=tf.nn.sigmoid)
])
# Konfiguration des Lernprozesses
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /home/lanahr/dev/EigeneKIAnwendungen01/.venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-17 10:54:15.374557: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# Trainieren

# %%
# 30 Durchläufe
model.fit(train_data, train_col, epochs=30)
# Out:
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3167 - loss: 1.1014
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3167 - loss: 1.0957
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2917 - loss: 1.0896
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3500 - loss: 1.0854
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3500 - loss: 1.0830
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3500 - loss: 1.0791
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3500 - loss: 1.0757
# Epoch 8/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3500 - loss: 1.0717
# Epoch 9/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3500 - loss: 1.0671
# Epoch 10/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3500 - loss: 1.0617
# Epoch 11/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3500 - loss: 1.0560
# Epoch 12/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4250 - loss: 1.0491
# Epoch 13/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5250 - loss: 1.0413
# Epoch 14/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6000 - loss: 1.0326
# Epoch 15/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6083 - loss: 1.0239
# Epoch 16/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6667 - loss: 1.0126
# Epoch 17/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6833 - loss: 1.0002
# Epoch 18/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6833 - loss: 0.9868
# Epoch 19/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6833 - loss: 0.9709
# Epoch 20/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6833 - loss: 0.9547
# Epoch 21/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6833 - loss: 0.9366
# Epoch 22/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6833 - loss: 0.9177
# Epoch 23/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6833 - loss: 0.8970
# Epoch 24/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6833 - loss: 0.8764
# Epoch 25/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6833 - loss: 0.8547
# Epoch 26/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6833 - loss: 0.8320
# Epoch 27/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6833 - loss: 0.8098
# Epoch 28/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6833 - loss: 0.7862
# Epoch 29/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6833 - loss: 0.7637
# Epoch 30/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6833 - loss: 0.7419

# %% [markdown]
# Testen

# %%
test_loss, test_acc = model.evaluate(test_data, test_col)
print('Test accuracy:', test_acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6000 - loss: 0.7383
# Test accuracy: 0.6000000238418579
